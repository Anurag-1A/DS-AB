# %% [markdown]
# <a href="https://colab.research.google.com/github/Anurag-1A/DS-AB/blob/main/Exploratory_Data_Analysis_(Airbnb_dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Airbnb Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on the exploratory data analysis (EDA) of Airbnb listings in New York City. The goal is to provide insights to help Airbnb hosts, property managers, and investors optimize their listings for improved occupancy rates and revenue.
#
# The dataset includes significant number of Airbnb listings from across New York City, with attributes such as neighborhood group, price, room type, reviews, and availability. Key features like price and room type were used to identify trends and patterns in the Airbnb market.
#
# The data was first cleaned to handle missing values,checked for duplicates and unique values. The essential features for analysis, such as neighborhood, price, and availability, were kept and last review column was dropped as it has missing values and wasn't necessary for our analysis. These steps ensured that the dataset was reliable for further analysis.
#
# Exploratory Data Analysis (EDA)
# The EDA aimed to uncover trends related to pricing, availability, and review counts etc and the analysis helped in understanding which neighborhoods and room types were more popular and successful. Some of the key insights observed were:
#
#  - Price Distribution by Neighborhood and Room Type: Listings in Manhattan had the highest prices, followed by Brooklyn, while Staten Island and the Bronx had the lowest. Entire homes and apartments were priced higher than private rooms, with substantial variability even within boroughs.
#
#  - Availability Trends: Central areas like Manhattan had lower availability, as they were more frequently booked. In contrast, listings in less popular areas such as Staten Island and the Bronx had higher availability, signaling lower demand. This suggests that hosts in less popular areas might need to adjust their pricing or marketing strategies.
#
#  - Review and Listing Popularity:Listings with higher numbers of reviews tended to have more competitive pricing and higher booking rates. Popular neighborhoods like Manhattan and Brooklyn received more reviews, indicating higher demand and better guest experiences.
#
# Some of the Key Insights and Recommendations on the analysis are:
#
#  - Neighborhood Selection: Manhattan and Brooklyn are premium locations but also highly competitive. Hosts in these areas need to differentiate their listings to stand out. In contrast, underrepresented areas like Staten Island and the Bronx offer potential for growth if hosts adopt effective pricing and marketing strategies.
#
#  - Room Type Strategy: Entire homes and apartments, especially in high-demand areas, command higher prices. However, private rooms in budget-friendly neighborhoods like Queens cater well to cost-conscious travelers, offering a balance between price and location.
#
#  - Pricing Optimization:Dynamic pricing models that adjust based on demand, seasonality, and competition can help hosts in high-demand areas maximize revenue. Properties with more reviews and lower pricing often outperform more expensive options.
#
#  - Listing Improvements: Hosts in lower-demand areas should focus on enhancing guest experiences and improving listing visibility through marketing to attract more bookings.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The core issue addressed in this project is the need for understanding the factors that influence Airbnb prices in New York City and also to help Airbnb hosts and property managers to enhance their listing performance by understanding key factors that drive pricing, demand, and availability across various neighborhoods in New York City. The objective is to use these insights for developing new strategies and enhancing the existing ones for better returns.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this exploratory data analysis is to help Airbnb hosts, property managers, and investors optimize their listings to improve occupancy rates, revenue, and overall performance.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Fetching dataset uploaded on github
# !wget https://raw.githubusercontent.com/Anurag-1A/DS-AB/refs/heads/main/Airbnb%20NYC%202019.csv
# Out:
# --2024-09-27 18:15:18--  https://raw.githubusercontent.com/Anurag-1A/DS-AB/refs/heads/main/Airbnb%20NYC%202019.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7077973 (6.8M) [text/plain]
# Saving to: ‘Airbnb NYC 2019.csv.1’
#
# Airbnb NYC 2019.csv 100%[===================>]   6.75M  --.-KB/s    in 0.1s
#
# 2024-09-27 18:15:18 (64.5 MB/s) - ‘Airbnb NYC 2019.csv.1’ saved [7077973/7077973]

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
filepath = 'Airbnb NYC 2019.csv'
read_airbnb_data = pd.read_csv(filepath)

#making a copy of the original dataset
df = read_airbnb_data.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
#Dataset at a glance
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info
# Out:
# <bound method DataFrame.info of              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The above dataset has 48,895 rows and 16 columns. There are no duplicate values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - id: A unique identifier assigned to each listing in the dataset.
# - name: The title or name of the listing as it is displayed on Airbnb's platform.
# - Host_id: A distinct identifier assigned to each host in the dataset.
# - Host_name: The name of the host as shown on Airbnb’s website.
# - Neighbourhood_group: A classification of neighborhoods within New York City, like Manhattan or Brooklyn.
# - Neighbourhood: The exact neighborhood where the listing is located.
# - Latitude: The geographical latitude coordinate of the listing.
# - Longitude: The geographical longitude coordinate of the listing.
# - Room_type: The category of accommodation being offered, such as an entire home, private room, or shared space.
# - Price: The nightly rate for staying at the listing, in US dollars.
# - Minimum_nights: The least number of nights required for a booking at the listing.
# - Total_reviews: The cumulative number of reviews the listing has received.
# - Reviews_per_month: The average number of reviews the listing gets each month.
# - Host_listings_count: The total number of listings that a particular host has on Airbnb.
# - Availability_365: The number of days in the upcoming 365-day period that the listing is available for reservation.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  id is 48895 .
# No. of unique values in  name is 47905 .
# No. of unique values in  host_id is 37457 .
# No. of unique values in  host_name is 11452 .
# No. of unique values in  neighbourhood_group is 5 .
# No. of unique values in  neighbourhood is 221 .
# No. of unique values in  latitude is 19048 .
# No. of unique values in  longitude is 14718 .
# No. of unique values in  room_type is 3 .
# No. of unique values in  price is 674 .
# No. of unique values in  minimum_nights is 109 .
# No. of unique values in  number_of_reviews is 394 .
# No. of unique values in  last_review is 1764 .
# No. of unique values in  reviews_per_month is 937 .
# No. of unique values in  calculated_host_listings_count is 47 .
# No. of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#Handling column values
df['host_name'].fillna('N/A',inplace=True)
df['name'].fillna('N/A',inplace=True)
df['reviews_per_month'].fillna(0, inplace=True)

#Dropping the last_review as we won't be utilizing it
df.drop(['last_review'],axis=1,inplace=True)

# %%
#Checking for unique neighbourhoods
df['neighbourhood'].nunique()
# Out:
# 221

# %%
print(df['host_name'].nunique())
print(df['name'].nunique())
# Out:
# 11453
# 47906

# %%
print(df.isnull().sum())
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The missing values Name and Host name columns are filled with 'N/A' since their count is very low and it won't make much difference in our further analysis. The review_per_month column was filled with 0 where the values were missing, which typically means that the property has not received any reviews, so assuming the same for our case and replacing with null values with 0 makes sense.
#
# Insights:
# Neighborhood Diversity: There are 221 unique neighborhoods in the dataset, indicating that the Airbnb listings span many distinct areas.
#
# Host Activity: The presence of 11,453 unique hosts suggests a large number of individuals or organizations offering properties for rent. There may be opportunities to analyze how certain hosts perform (e.g., comparing hosts with many listings vs. those with fewer).
#
# Variety of Listings: With 47,906 unique listings, the dataset contains a wide range of property types and names. This level of diversity could be useful for identifying trends in listing types, popular names, or property characteristics.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
host_listings = df.groupby('host_name')['calculated_host_listings_count'].sum()

# Sort the results in descending order
top_hosts = host_listings.sort_values(ascending=False).head(10)

print(top_hosts)

# Plot the dot plot
plt.figure(figsize=(12, 8))
plt.scatter(top_hosts.index, top_hosts, color='purple')
plt.title('Top 10 Hosts by Total Number of Listings')
plt.xlabel('Host Name')
plt.ylabel('Total Number of Listings')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# host_name
# Sonder (NYC)         106929
# Blueground            53824
# Kara                  14679
# Kazuya                10609
# Sonder                 9216
# Jeremy & Laura         9216
# Corporate Housing      8281
# Ken                    7645
# Pranjal                4225
# Mike                   2910
# Name: calculated_host_listings_count, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A dot plot is ideal for comparing the number of listings held by each host, as it clearly shows the distribution of listings across multiple hosts without overlapping data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The dot plot reveals that a small number of hosts hold a significant number of listings. Among the top 10 hosts, some manage far more properties than others, creating a large gap between the highest and lowest in this group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights helps in the understanding market dominance. For Airbnb management companies or stakeholders, it provides a clear view of who the major players are. Hosts with fewer listings can identify the strategies of these top hosts to potentially expand their own portfolios.

# %% [markdown]
# #### Chart - 2

# %%
# Plotting a histogram of the 'price' column
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Prices in Airbnb Listings')
plt.xlabel('Price ($)')
plt.ylabel('Frequency of Listings')
plt.grid(True)
plt.show()

#Applying Log transformation on y-axis for better visualization
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Prices in Airbnb Listings')
plt.xlabel('Price ($)')
plt.ylabel('Frequency of Listings')
plt.yscale('log')  # Using a logarithmic scale to better visualize the distribution
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The purpose of using the histogram chart above is to show the distribution of prices across all listings.I chose a histogram chart as it is ideal for understanding the distribution of a numerical variable. In this case, the chart helps is to visualize how prices are spread across different ranges

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - >  From the above histogram, we can observe that as prices increase the number of listing decreases i.e. there are man listing around the $500 and below.
#
# - > From the first histogram we figure out that the distribution is right skewed i.e. there are few listings with very high price pull
# By applying a logarithimic scale on the frequency of listing we are trying to visualize the data on lesser frequency end.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the above insights will help hosts and property managers price their listings competitively. Most listings are in the affordable range, so adjusting pricing to align with market norms can boost occupancy.

# %% [markdown]
# #### Chart - 3

# %%
# Count the occurrences of each neighbourhood group
neighbourhood_counts = df['neighbourhood_group'].value_counts()

# Create a bar chart
plt.figure(figsize=(10, 7))
neighbourhood_counts.plot(kind='bar', color=plt.cm.Paired.colors)

# Add labels and title
plt.title('Distribution of Neighbourhood Groups')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Number of Listings')

# Add percentage labels on top of each bar
for i, count in enumerate(neighbourhood_counts):
    plt.text(i, count + (0.01 * max(neighbourhood_counts)), #0.01 * max(neighbourhood_counts) calculates 1% of the maximum value of neighbourhood_counts and adds this as extra space above each bar
             f'{count / neighbourhood_counts.sum() * 100:.1f}%', ha='center', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used to compare different categories, in this case, the number of listings in each neighborhood. This chart was selected because it allows for easy comparison of how listings are distributed across different neighborhoods, making it clear which areas are more popular for Airbnb hosts and guests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - > The bar chart helps to identify and visualise the total number of listing individually for each neighbourhood. It indicates that Manhattan and Brooklyn are the most sought-after neighborhoods, followed  by Queens.
#
# - > In contrast, Staten Island and the Bronx together hosts only 3% of the total listed properties and have the fewest listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding neighborhood demand helps investors and hosts target the right areas. High demand in Manhattan and Brooklyn suggests greater competition but also more opportunities for occupancy.
#
# A probable negative point is that high competition in Manhattan could make it harder for new listings to stand out, leading to lower bookings if not managed properly.

# %% [markdown]
# #### Chart - 4

# %%
avg_prices = df.groupby(['neighbourhood_group', 'room_type'])['price'].mean().unstack()

# Plot the grouped bar chart
avg_prices.plot(kind='bar', figsize=(14, 8), colormap='Paired')

# Add labels and title
plt.title('Average Price by Room Type and Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Price (USD)')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  By using a multiple bar chart we are trying to visuzlise the relationship between two categorical variables (neighborhood_group and room_type) and a numerical value (average price) in a clear and visually appealing manner. This chart provides a clear view of average price differences between room types in each area.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  - Entire home/apt consistently commands the highest average price across all neighborhoods.
#  - Shared room has the lowest average price, making it the most affordable in every neighborhood.
#  - The price gap between room types is most apparent in Manhattan, indicating a higher premium for private and entire home/apt accommodations in this neighborhood.
#  - Bronx is the suitable option for those people who are looking for large spaces(aparment/home) with low budgets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The above chart and insights can help the hosts decide which type of listing to offer in different neighborhoods. For example, if maximizing revenue is the goal, offering entire homes in Manhattan is beneficial. Meanwhile, shared rooms are ideal for budget travelers.

# %% [markdown]
# #### Chart - 5

# %%
#Calculates the total count for each room type
room_type_counts = df['room_type'].value_counts()

#pie chart
plt.figure(figsize=(8, 8))
plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Distribution of Room Types in Airbnb NYC 2019')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is ideal for showing the proportion of categories within a whole. Here, it was used to represent the distribution of room types (Entire home/apartment, Private room, Shared room) across Airbnb listings in NYC.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  - > The majority of listings are for "Entire home/apartment" constituting 52.0% of the total listing.
#  - > The most prevalent room type on Airbnb NYC in 2019 was "Entire home/apt," accounting for 52% of the market.
#  - > Shared room" was the least common room type, representing only 2.4% of the listings.
#
# This indicates a strong preference among both hosts and guests for entire properties or private rooms over shared accommodations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, hosts can tailor their offerings based on demand. With more than half the market preferring entire homes, hosts may want to focus on offering this type of accommodation to increase occupancy and revenue.

# %% [markdown]
# #### Chart - 6

# %%
avg_prices = df.groupby('neighbourhood_group')['price'].mean().reset_index()

# Find the most expensive and least expensive neighbourhoods
most_expensive = avg_prices.loc[avg_prices['price'].idxmax()]
least_expensive = avg_prices.loc[avg_prices['price'].idxmin()]

# Combine the results into a single DataFrame
expensive_neighbourhoods = pd.DataFrame({
    'Neighbourhood Group': [most_expensive['neighbourhood_group'], least_expensive['neighbourhood_group']],
    'Average Price (USD)': [most_expensive['price'], least_expensive['price']]
}, index=['Most Expensive', 'Least Expensive'])

# Reset index to use it for plotting
expensive_neighbourhoods = expensive_neighbourhoods.reset_index().rename(columns={'index': 'Category'})

print(expensive_neighbourhoods)

# Plotting
plt.figure(figsize=(10, 6))
colors = ['#ff9999','#66b3ff']  # Define colors for the bars

# Create horizontal bar chart
plt.barh(expensive_neighbourhoods['Category'], expensive_neighbourhoods['Average Price (USD)'], color=colors)

# Add text labels showing the Neighbourhood Group next to the bars
for i, (avg_price, neighbourhood) in enumerate(zip(expensive_neighbourhoods['Average Price (USD)'], expensive_neighbourhoods['Neighbourhood Group'])):
    plt.text(avg_price + 1, i, f"{neighbourhood}", va='center', fontsize=12)

# Adding labels and title for the chart
plt.xlabel('Average Price (USD)')
plt.title('Comparison of Most and Least Expensive Neighbourhoods')


plt.xlim(0, expensive_neighbourhoods['Average Price (USD)'].max() + 50)  # Adding some extra space on x-axis
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#           Category Neighbourhood Group  Average Price (USD)
# 0   Most Expensive           Manhattan           196.875814
# 1  Least Expensive               Bronx            87.496792

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a horizontal bar chart to compare the most and least expensive neighborhoods because, it visually presents and highlights the neighborhoods with the highest and lowest average prices clearly, allowing stakeholders to quickly grasp the price variation across neighborhoods.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan being the most expensive neighbourhood with the highest average price we can infer that it could be driven by higher demand, location, and exclusivity.
# Meanwhile Bronx, have much lower average prices, indicating this particular area could be catering to a different demographic or perhaps offering fewer amenities

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There is potential a negative growth point wherein highly expensive neighborhood, if the prices are pushed too high, it could lead to lower occupancy rates, especially among price-sensitive travelers or during off-peak seasons this in turn can result in a significant loss to the host as well as airbnb.

# %% [markdown]
# #### Chart - 7

# %%
avg_availability = df.groupby('neighbourhood_group')['availability_365'].mean().reset_index()

# Neighbourhoods with the highest and lowest availability
most_available = avg_availability.loc[avg_availability['availability_365'].idxmax()]
least_available = avg_availability.loc[avg_availability['availability_365'].idxmin()]

# Combining the results into a single DataFrame
availability_neighbourhoods = pd.DataFrame({
    'Neighbourhood Group': [most_available['neighbourhood_group'], least_available['neighbourhood_group']],
    'Average Availability (days per year)': [most_available['availability_365'], least_available['availability_365']]
}, index=['Most Available', 'Least Available'])

# Resetting index for plotting
availability_neighbourhoods = availability_neighbourhoods.reset_index().rename(columns={'index': 'Category'})

# Plot the chart
plt.figure(figsize=(10, 6))
colors = ['#66b3ff','#ff9999']  # colors used for the bars

# Creatting horizontal bar chart
plt.barh(availability_neighbourhoods['Category'], availability_neighbourhoods['Average Availability (days per year)'], color=colors)

# Adding text labels showing the Neighbourhood Group name on top/next to the bars
for i, (avg_availability, neighbourhood) in enumerate(zip(availability_neighbourhoods['Average Availability (days per year)'], availability_neighbourhoods['Neighbourhood Group'])):
    plt.text(avg_availability + 2, i, f"{neighbourhood}", va='center', fontsize=12)

# Add labels and title
plt.xlabel('Average Availability (days per year)')
plt.title('Neighbourhoods with Highest and Lowest Availability')

# Adjust layout for better appearance
plt.xlim(0, availability_neighbourhoods['Average Availability (days per year)'].max() + 20)  # Add some space on x-axis
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  A horizontal bar chart allows for easy comparison of the number of available days per year, which helps in clearly identifying extremes—areas with the most and least available Airbnb listings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Staten Island has the highest average availability, with listings being available for around 200 days per year.
# Brooklyn has the lowest availability, with listings available for fewer than 100 days per year.
# These insights showcases the demand-supply dynamics in different neighborhoods. Areas with higher availability may have lower demand, while those with lower availability are likely in high demand or have fewer listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Negative growth would be for Brooklyn where the low availability might signal a saturated market and new listings might struggle to secure bookings unless they offer something unique or are competitively priced.

# %% [markdown]
# #### Chart - 8

# %%
plt.figure(figsize=(14, 8))
sns.stripplot(x='neighbourhood_group', y='reviews_per_month', hue='room_type', data=df, palette='Set2', jitter=True, dodge=True)
plt.xlabel('Neighbourhood Group')
plt.ylabel('Reviews Per Month')
plt.title('Distribution of Reviews Per Month by Room Type in Each Neighbourhood Group')
plt.xticks(rotation=45)
plt.legend(title='Room Type')
plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a scatter plot for this analysis because it effectively visualizes the distribution of reviews per month across different room types and neighborhoods. This chart makes it easy to see variations in the number of reviews each type of listing (private room, entire home/apartment, shared room) receives, as well as compare the overall activity in different neighborhoods.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - > Private rooms (green) and entire homes/apartments (orange) generally receive higher review counts compared to shared rooms, indicating their popularity among guests.
#
# - > Staten Island and the Bronx show lower overall review counts across all room types, which may indicate less activity or fewer listings in these neighborhoods.
#
# - > Outliers: There are some notable outliers, particularly for private rooms in Manhattan and Queens. In Manhattan, some private room listings have as many as 30 and 60 reviews per month, while in Queens, there are listings with 20+ reviews per month.
#
# These insights highlight how demand varies not only by neighborhood but also by the type of accommodation being offered.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:
# Targeting high-demand listings: The outliers (listings with high reviews per month) in Manhattan and Queens highlight opportunities for hosts to replicate successful strategies—whether it’s pricing, location, or listing quality.
#
# Listings in neighborhoods with low review numbers (e.g., Staten Island or Bronx) may benefit from improved marketing or differentiated pricing strategies to increase demand.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# - Neighborhood Selection:
# Prioritize neighborhoods like Manhattan and Brooklyn for higher returns, but be aware of the need to stand out in these competitive markets.
# Explore less crowded areas such as Staten Island and the Bronx, which offer more affordable entry options with potential for future growth.
#
# - Room Type Strategy:
# Focus on renting out entire homes in areas with high demand, as these tend to be more popular and can command premium prices.
# Consider offering private rooms in more budget-friendly areas, such as Queens or the Bronx, to cater to cost-conscious travelers.
#
# - Pricing Optimization:
# Strive to balance pricing with guest satisfaction. Properties priced lower with more reviews can gain greater visibility and bookings over time.
# Adjust prices according to availability and competition in the neighborhood to optimize occupancy.
#
# - Enhancing Listing Appeal:
# Prioritize enhancing the guest experience and improving the property's appeal to boost positive reviews, which can directly increase bookings and occupancy rates.
#
# - Marketing Recommendations:
# Use insights from underperforming neighborhoods to direct marketing strategies. Increase exposure for listings in areas with lower demand, such as Staten Island or the Bronx.
# By adopting these data-driven strategies, hosts and investors can enhance their property's performance and remain competitive in New York's fast-moving Airbnb market.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This exploratory data analysis provides a detailed understanding of the Airbnb market in New York City. By examining factors such as price, availability, and neighborhood demand, stakeholders can make informed decisions regarding pricing, investment, and marketing strategies. Future work could include analyzing additional years of data or incorporating external factors such as tourism trends or regulatory changes affecting short-term rentals.
